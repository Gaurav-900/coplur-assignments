# %% [markdown]
# ## Q1.py

# %%
#1) Practise print statement ─

# multiple objects
print("Hello", "World", 42, 3.14)
 
# separator
print("apple", "banana", "Mango", sep=" | ")
 
# end
print("wait", end=" ")
print("")

# %% [markdown]
# ## Q2.py

# %%
#2) Greeting with user input ─
 
name = input("Please enter your name: ")
print("Hello", name, "have a great day")
