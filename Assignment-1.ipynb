# %%
# 1) Practise print statement: - with multiple object - with seperator - with "ends"

# multiple objects
print("Hello", "World", 42, 3.14)
 
# separator
print("apple", "banana", "Mango", sep=" | ")
 
# end
print("wait", end=" ")
print("")
# Out:
# Hello World 42 3.14
# apple | banana | Mango
# wait

# %%
# 2) Using input ask user to enter his/her name and output user name with a greeting message


 
name = input("Please enter your name: ")
print("Hello", name, "have a great day")
# Out:
# Hello Python have a great day
